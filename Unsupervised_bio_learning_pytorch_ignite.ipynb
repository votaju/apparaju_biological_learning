# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.io
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

from ignite.engine import Events, create_supervised_trainer, create_supervised_evaluator
from ignite.metrics import Accuracy, Loss
from sklearn import preprocessing
from time import time

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Initialize variables required for the algorithm

learning_rate = 2e-2    # initial learning rate
Kx = 10
Ky = 10
n_hidden = 2000         # number of hidden units in hidden layer
mu = 0.0                # mean for gaussian distribution to initialize weights with
sigma = 1.0             # standard deviation for gaussian distribution to initialize weights with
n_epochs = 200          # number of epochs
batch_size = 100        # size of the minibatch
precision = 1e-30       # parameter to control numerical precision of weight updates
anti_hebbian_learning_strength = 0.4    # Strength of the anti-hebbian learning
lebesgue_norm = 2.0                     # Lebesgue norm of the weights
rank = 2                                # ranking parameter, must be integer that is bigger or equal than 2

# %%
# Initialize variables required for the algorithm
# Best values according to paper

learning_rate = 2e-2    # initial learning rate
Kx = 10
Ky = 10
n_hidden = 2000         # number of hidden units in hidden layer
mu = 0.0                # mean for gaussian distribution to initialize weights with
sigma = 1.0             # standard deviation for gaussian distribution to initialize weights with
n_epochs = 200          # number of epochs
batch_size = 100        # size of the minibatch
precision = 1e-30       # parameter to control numerical precision of weight updates
anti_hebbian_learning_strength = 0.4    # Strength of the anti-hebbian learning
lebesgue_norm = 3.0                     # Lebesgue norm of the weights
rank = 7                                # ranking parameter, must be integer that is bigger or equal than 2

# %%
# UNSUPERVISED 'BIO' LEARNING ALGORITHM

# Define function that performs the unsupervised learning and returns weights
# that correspond to feature detectors.
# Uses cuda if available.
def get_unsupervised_weights(data, n_hidden, n_epochs, batch_size, learning_rate, precision, 
                             anti_hebbian_learning_strength, lebesgue_norm, rank):
    print("Starting unsupervised bio-plausible training")
    
    num_samples = data.shape[0]   # Number of samples/images.
    num_features = data.shape[1]  # Number of pixels for each sample/image.
    
    # Initialize weights to be values drawn from gaussian distribution.
    synapses = np.random.normal(mu, sigma, (n_hidden, num_features)).astype(np.float32)
    weights = torch.from_numpy(synapses).to(device)

    # The external loop runs over epochs
    for epoch in range(n_epochs):
        eps = learning_rate * (1 - epoch / n_epochs)

        # Scramble the images and values. So that when making a
        # mini batch, random values/images will be chosen on each iteration.
        random_permutation_samples = np.random.permutation(num_samples)
        shuffled_epoch_data = data[random_permutation_samples,:]

        # Internal loop runs over minibatches    
        for i in range(num_samples // batch_size):        
            # For every minibatch the overlap with the data (tot_input) is 
            # calculated for each data point and each hidden unit.
            mini_batch = shuffled_epoch_data[i*batch_size:(i+1)*batch_size,:].astype(np.float32)
            mini_batch = torch.from_numpy(mini_batch).to(device)           
            mini_batch = torch.transpose(mini_batch, 0, 1)

            sign = torch.sign(weights)            
            W = sign * torch.abs(weights) ** (lebesgue_norm - 1)    
            # https://stackoverflow.com/questions/44524901/how-to-do-product-of-matrices-in-pytorch
            tot_input_torch = torch.mm(W, mini_batch)

            # The sorted strengths of the activations are stored in y. 
            # The variable yl stores the activations of the post synaptic cells - 
            # it is denoted by g(Q) in Eq 3 of 'Unsupervised Learning by Competing Hidden Units', see also Eq 9 and Eq 10.        
            y_torch = torch.argsort(tot_input_torch, dim=0)            
            yl_torch = torch.zeros((n_hidden, batch_size), dtype = torch.float).to(device)
            yl_torch[y_torch[n_hidden-1,:], torch.arange(batch_size)] = 1.0
            yl_torch[y_torch[n_hidden-rank], torch.arange(batch_size)] = -anti_hebbian_learning_strength

            # The variable ds is the right hand side of Eq 3        
            xx_torch = torch.sum(yl_torch * tot_input_torch,1)  
            xx_torch = xx_torch.unsqueeze(1)                    
            xx_torch = xx_torch.repeat(1, num_features)
            ds_torch = torch.mm(yl_torch, torch.transpose(mini_batch, 0, 1)) - (xx_torch * weights)

            # Update weights
            # The weights are updated after each minibatch in a way so that the largest update 
            # is equal to the learning rate eps at that epoch.        
            nc_torch = torch.max(torch.abs(ds_torch))
            if nc_torch < precision: 
                nc_torch = precision            
            weights += eps*(ds_torch/nc_torch)

            #if (i+1) % 100 == 0:
            #    print (f'Epoch [{epoch+1}/{n_epochs}], Step [{i+1}/{num_samples // batch_size}]')

        print (f'Epoch [{epoch+1}/{n_epochs}]')
        
    print("Completed unsupervised bio-plausible training")
    return weights
    #return weights.cpu().numpy()

# %%
# LOAD AND PREPARE MNIST DATA FOR UNSUPERVISED TRAINING

print("Loading MNIST...")
mat = scipy.io.loadmat('mnist_all.mat')
print("Done loading MNIST")
#print(mat)

Nc=10 # number of classes
N=784 # number of pixels for each image. 28x28

M=np.zeros((0,N))
for i in range(Nc):
    M=np.concatenate((M, mat['train'+str(i)]), axis=0)
M=M/255.0

data_mnist = M
print(f'Number of samples: {data_mnist.shape[0]}')
print(f'Number of features: {data_mnist.shape[1]}')
# Out:
# Loading MNIST...
# Done loading MNIST
# Number of samples: 60000
# Number of features: 784

# %%
# RUN UNSUPERVISED 'BIO' LEARNING ALGORITHM for MNIST

# Calculates weights for data and provided number of hidden units (given other configuration)
weights_mnist = get_unsupervised_weights(data_mnist, n_hidden, n_epochs, batch_size, learning_rate, precision, 
                                         anti_hebbian_learning_strength, lebesgue_norm, rank)
#print(weights_mnist.shape)
#print(weights_mnist)

# Keep backups of these weights
weights_mnist_backup = weights_mnist
weights_mnist_frozen = weights_mnist

# TODO Maybe write these to file to keep?
# Out:
# Starting unsupervised bio-plausible training
# Epoch [1/200]
# Epoch [2/200]
# Epoch [3/200]
# Epoch [4/200]
# Epoch [5/200]
# Epoch [6/200]
# Epoch [7/200]
# Epoch [8/200]
# Epoch [9/200]
# Epoch [10/200]
# Epoch [11/200]
# Epoch [12/200]
# Epoch [13/200]
# Epoch [14/200]
# Epoch [15/200]
# Epoch [16/200]
# Epoch [17/200]
# Epoch [18/200]
# Epoch [19/200]
# Epoch [20/200]
# Epoch [21/200]
# Epoch [22/200]
# Epoch [23/200]
# Epoch [24/200]
# Epoch [25/200]
# Epoch [26/200]
# Epoch [27/200]
# Epoch [28/200]
# Epoch [29/200]
# Epoch [30/200]
# Epoch [31/200]
# Epoch [32/200]
# Epoch [33/200]
# Epoch [34/200]
# Epoch [35/200]
# Epoch [36/200]
# Epoch [37/200]
# Epoch [38/200]
# Epoch [39/200]
# Epoch [40/200]
# Epoch [41/200]
# Epoch [42/200]
# Epoch [43/200]
# Epoch [44/200]
# Epoch [45/200]
# Epoch [46/200]
# Epoch [47/200]
# Epoch [48/200]
# Epoch [49/200]
# Epoch [50/200]
# Epoch [51/200]
# Epoch [52/200]
# Epoch [53/200]
# Epoch [54/200]
# Epoch [55/200]
# Epoch [56/200]
# Epoch [57/200]
# Epoch [58/200]
# Epoch [59/200]
# Epoch [60/200]
# Epoch [61/200]
# Epoch [62/200]
# Epoch [63/200]
# Epoch [64/200]
# Epoch [65/200]
# Epoch [66/200]
# Epoch [67/200]
# Epoch [68/200]
# Epoch [69/200]
# Epoch [70/200]
# Epoch [71/200]
# Epoch [72/200]
# Epoch [73/200]
# Epoch [74/200]
# Epoch [75/200]
# Epoch [76/200]
# Epoch [77/200]
# Epoch [78/200]
# Epoch [79/200]
# Epoch [80/200]
# Epoch [81/200]
# Epoch [82/200]
# Epoch [83/200]
# Epoch [84/200]
# Epoch [85/200]
# Epoch [86/200]
# Epoch [87/200]
# Epoch [88/200]
# Epoch [89/200]
# Epoch [90/200]
# Epoch [91/200]
# Epoch [92/200]
# Epoch [93/200]
# Epoch [94/200]
# Epoch [95/200]
# Epoch [96/200]
# Epoch [97/200]
# Epoch [98/200]
# Epoch [99/200]
# Epoch [100/200]
# Epoch [101/200]
# Epoch [102/200]
# Epoch [103/200]
# Epoch [104/200]
# Epoch [105/200]
# Epoch [106/200]
# Epoch [107/200]
# Epoch [108/200]
# Epoch [109/200]
# Epoch [110/200]
# Epoch [111/200]
# Epoch [112/200]
# Epoch [113/200]
# Epoch [114/200]
# Epoch [115/200]
# Epoch [116/200]
# Epoch [117/200]
# Epoch [118/200]
# Epoch [119/200]
# Epoch [120/200]
# Epoch [121/200]
# Epoch [122/200]
# Epoch [123/200]
# Epoch [124/200]
# Epoch [125/200]
# Epoch [126/200]
# Epoch [127/200]
# Epoch [128/200]
# Epoch [129/200]
# Epoch [130/200]
# Epoch [131/200]
# Epoch [132/200]
# Epoch [133/200]
# Epoch [134/200]
# Epoch [135/200]
# Epoch [136/200]
# Epoch [137/200]
# Epoch [138/200]
# Epoch [139/200]
# Epoch [140/200]
# Epoch [141/200]
# Epoch [142/200]
# Epoch [143/200]
# Epoch [144/200]
# Epoch [145/200]
# Epoch [146/200]
# Epoch [147/200]
# Epoch [148/200]
# Epoch [149/200]
# Epoch [150/200]
# Epoch [151/200]
# Epoch [152/200]
# Epoch [153/200]
# Epoch [154/200]
# Epoch [155/200]
# Epoch [156/200]
# Epoch [157/200]
# Epoch [158/200]
# Epoch [159/200]
# Epoch [160/200]
# Epoch [161/200]
# Epoch [162/200]
# Epoch [163/200]
# Epoch [164/200]
# Epoch [165/200]
# Epoch [166/200]
# Epoch [167/200]
# Epoch [168/200]
# Epoch [169/200]
# Epoch [170/200]
# Epoch [171/200]
# Epoch [172/200]
# Epoch [173/200]
# Epoch [174/200]
# Epoch [175/200]
# Epoch [176/200]
# Epoch [177/200]
# Epoch [178/200]
# Epoch [179/200]
# Epoch [180/200]
# Epoch [181/200]
# Epoch [182/200]
# Epoch [183/200]
# Epoch [184/200]
# Epoch [185/200]
# Epoch [186/200]
# Epoch [187/200]
# Epoch [188/200]
# Epoch [189/200]
# Epoch [190/200]
# Epoch [191/200]
# Epoch [192/200]
# Epoch [193/200]
# Epoch [194/200]
# Epoch [195/200]
# Epoch [196/200]
# Epoch [197/200]
# Epoch [198/200]
# Epoch [199/200]
# Epoch [200/200]
# Completed unsupervised bio-plausible training

# %%
# SANITY CHECKS (for my sanity)

print(weights_mnist)
print()
print(weights_mnist_backup)
print()
print(weights_mnist_frozen)
print()

print(torch.all(weights_mnist.eq(weights_mnist_backup)))
print(torch.all(weights_mnist.eq(weights_mnist_frozen)))
print(torch.all(weights_mnist_frozen.eq(weights_mnist_backup)))

#print((weights_mnist==weights_mnist_backup).all())
#print((weights_mnist_frozen==weights_mnist_backup).all())
# Out:
# tensor([[-2.8026e-45, -2.8026e-45, -2.8026e-45,  ..., -2.8026e-45,
#           2.8026e-45,  2.8026e-45],
#         [-2.0217e-23,  4.6271e-23,  6.7561e-23,  ..., -4.9861e-24,
#           3.5312e-23,  4.2818e-24],
#         [ 2.8026e-45, -2.8026e-45,  2.8026e-45,  ...,  2.8026e-45,
#           2.8026e-45, -2.8026e-45],
#         ...,
#         [-6.3122e-15,  7.2653e-15,  8.3537e-15,  ...,  2.0500e-15,
#           4.1330e-15, -1.7043e-14],
#         [ 2.2871e-11, -2.6963e-11,  1.9305e-11,  ..., -1.2225e-11,
#          -2.8153e-12, -6.3358e-12],
#         [ 2.8026e-45, -2.8026e-45, -2.8026e-45,  ..., -2.8026e-45,
#           2.8026e-45, -2.8026e-45]], device='cuda:0')
#
# tensor([[-2.8026e-45, -2.8026e-45, -2.8026e-45,  ..., -2.8026e-45,
#           2.8026e-45,  2.8026e-45],
#         [-2.0217e-23,  4.6271e-23,  6.7561e-23,  ..., -4.9861e-24,
#           3.5312e-23,  4.2818e-24],
#         [ 2.8026e-45, -2.8026e-45,  2.8026e-45,  ...,  2.8026e-45,
#           2.8026e-45, -2.8026e-45],
#         ...,
#         [-6.3122e-15,  7.2653e-15,  8.3537e-15,  ...,  2.0500e-15,
#           4.1330e-15, -1.7043e-14],
#         [ 2.2871e-11, -2.6963e-11,  1.9305e-11,  ..., -1.2225e-11,
#          -2.8153e-12, -6.3358e-12],
#         [ 2.8026e-45, -2.8026e-45, -2.8026e-45,  ..., -2.8026e-45,
#           2.8026e-45, -2.8026e-45]], device='cuda:0')
#
# tensor([[-2.8026e-45, -2.8026e-45, -2.8026e-45,  ..., -2.8026e-45,
#           2.8026e-45,  2.8026e-45],
#         [-2.0217e-23,  4.6271e-23,  6.7561e-23,  ..., -4.9861e-24,
#           3.5312e-23,  4.2818e-24],
#         [ 2.8026e-45, -2.8026e-45,  2.8026e-45,  ...,  2.8026e-45,
#           2.8026e-45, -2.8026e-45],
#         ...,
#         [-6.3122e-15,  7.2653e-15,  8.3537e-15,  ...,  2.0500e-15,
#           4.1330e-15, -1.7043e-14],
#         [ 2.2871e-11, -2.6963e-11,  1.9305e-11,  ..., -1.2225e-11,
#          -2.8153e-12, -6.3358e-12],
#         [ 2.8026e-45, -2.8026e-45, -2.8026e-45,  ..., -2.8026e-45,
#           2.8026e-45, -2.8026e-45]], device='cuda:0')
#
# tensor(True, device='cuda:0')
# tensor(True, device='cuda:0')
# tensor(True, device='cuda:0')

# %%
# Draw MNIST weights/feature detectors generated by unsupervised bio algo

# REFERENCED FROM: https://github.com/DimaKrotov/Biological_Learning
# To draw a heatmap of the weights a helper function is created

def draw_weights(synapses, Kx, Ky):
    yy=0
    HM=np.zeros((28*Ky,28*Kx))
    for y in range(Ky):
        for x in range(Kx):            
            HM[y*28:(y+1)*28,x*28:(x+1)*28]=synapses[yy,:].reshape(28,28)            
            yy += 1
    plt.clf()
    nc=np.amax(np.absolute(HM))
    im=plt.imshow(HM,cmap='bwr',vmin=-nc,vmax=nc)
    fig.colorbar(im,ticks=[np.amin(HM), 0, np.amax(HM)])
    plt.axis('off')
    fig.canvas.draw() 

# %matplotlib inline
# %matplotlib notebook
fig=plt.figure(figsize=(12.9,10))
draw_weights(weights_mnist.cpu().numpy(), Kx, Ky)
print(weights_mnist.shape)
print("Fin")
# Out:
# <img src="data:image/png;base64,..." width="928">
# torch.Size([2000, 784])
# Fin

# %%
# DEFINE BioClassifier AND BioLoss CLASSES TO PERFORM BIO-PLAUSIBLE LEARNING

# REFERENCED FROM https://github.com/gatapia/unsupervised_bio_classifier

class BioCell(nn.Module):
    def __init__(self, Wui, beta, out_features):
        # Wui is the unsupervised pretrained weight matrix of shape: (2000, 28*28)
        
        super().__init__()
        # TODO: Does this need to be transposed here?
        # Answer: NO! Because we are using F.linear in the forward pass rather than multiplying directly ourselves.
        # F.linear does the transpose internally.
        self.Wui = Wui
        self.beta = beta
        self.supervised = nn.Linear(Wui.shape[0], out_features, bias=False)
        
    def forward(self, vi):
        Wui_vi = F.linear(vi, self.Wui, None)
        # Using basic RELU 
        hu = F.relu(Wui_vi)
        Sau = self.supervised(hu)
        ca = torch.tanh(self.beta * Sau)
        return ca

    
class BioCell2(nn.Module):
    def __init__(self, Wui, beta=0.1, out_features=10):
        # Wui is the unsupervised pretrained weight matrix of shape: (2000, 28*28)
        
        super().__init__()
        self.Wui = Wui.transpose(0, 1) # (768, 2000)
        self.beta = beta
        self.supervised = nn.Linear(Wui.shape[0], out_features, bias=False)
        
    def forward(self, vi):        
        # Different from BioCell where we do matmul here directly rather than using nn.Linear to accomplish the same.
        Wui_vi = torch.matmul(vi, self.Wui)
        # Using basic RELU 
        hu = F.relu(Wui_vi)
        Sau = self.supervised(hu)
        ca = torch.tanh(self.beta * Sau)
        return ca


class BioCell3(nn.Module):
    def __init__(self, Wui, n=4.5, beta=.01, out_features=10):
        # Wui is the unsupervised pretrained weight matrix of shape: (2000, 28*28)
        
        super().__init__()
        self.Wui = Wui.transpose(0, 1) # (768, 2000)
        self.n = n
        self.beta = beta
        # Below can be renamed to self.supervised to be similar to previous cells
        self.Sau = nn.Linear(Wui.shape[0], out_features, bias=False)
        
    def forward(self, vᵢ):
        # vᵢ = vᵢ.view(-1, 28, 28).transpose(1, 2).contiguous().view(-1, 28*28) # change vᵢ to be HxW for testing
        Wui_vi = torch.matmul(vi, self.Wui)
        # Using custom RELU as in the paper
        hu = F.relu(Wui_vi) ** self.n
        Sau_hu = self.Sau(hu)
        ca = torch.tanh(self.beta * Sau_hu)
        return ca

    
class BioLoss(nn.Module):
    def __init__(self, m=6):
        super().__init__()
        self.m = m

    # According to the hidden units paper, c = predictions, t = actual labels
    def forward(self, c, t):
        t_ohe = torch.eye(10, dtype=torch.float, device='cuda')[t]
        t_ohe[t_ohe==0] = -1.        
        loss = (c - t_ohe).abs() ** self.m
        return loss.sum()

    
class BioClassifier(nn.Module):
    def __init__(self, bio):
        super().__init__()
        self.bio = bio

    def forward(self, vi):
        ca = self.bio(vi)
        return F.log_softmax(ca, dim=-1)

# %%
# RESET weights (for my sanity)

weights_mnist = weights_mnist_frozen

# %%
# TRAIN USING BIOCLASSIFIER AND OBTAIN GENERALIZATION RESULTS
# Results: Accuracy of the network on the 10000 test images: 97.26 %

# REFERENCES: 
# - https://www.python-engineer.com/courses/pytorchbeginner/13-feedforward-neural-network/
# - https://github.com/gatapia/unsupervised_bio_classifier

# 0) Prepare data
# MNIST dataset 
print("Downloading MNIST data...")
train_dataset = torchvision.datasets.MNIST(root='./data', 
                                           train=True, 
                                           transform=transforms.ToTensor(),  
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root='./data', 
                                          train=False, 
                                          transform=transforms.ToTensor())

print("Completed downloading MNIST data.")

# Data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=False)

# Plot some sample data for sanity check
#examples = iter(test_loader)
#example_data, example_targets = examples.next()
#%matplotlib inline
#%matplotlib notebook
#for i in range(6):
#    plt.subplot(2,3,i+1)
#    plt.imshow(example_data[i][0], cmap='gray')
#plt.show()


# 1) Design and init model
#model = BioClassifier(BioCell2(weights_mnist)).to(device)
model = BioClassifier(BioCell3(weights_mnist)).to(device)

# Print the named parameters to test that model initialised correctly. 
# Names parameter that requires grad should be only S.weight.
print(f'Printing named parameters for the generated BioClassifier model.')
for name, param in model.named_parameters():
    if param.requires_grad:
        print(name, param.data)
print()


# 2) Construct loss and optimizer
criterion = BioLoss(m=6)
#criterion = nn.NLLLoss()
supervised_learning_rate = 1e-4
optimizer = torch.optim.Adam(model.parameters(), lr=supervised_learning_rate) 


# 3) Train the model - training loop
n_total_steps = len(train_loader)
print(f'n_total_steps: {n_total_steps}')
n_supervised_epochs = 300
print(f'n_supervised_epochs: {n_supervised_epochs}')

print('Start training...')
for epoch in range(n_supervised_epochs):
    print()
    for i, (images, labels) in enumerate(train_loader):
        
        # origin images shape: [100, 1, 28, 28]
        # resized: [100, 784]
        images = images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        
        # predict = forward pass
        outputs = model(images)

        # calculate loss
        loss = criterion(outputs, labels)

        # backward pass to calculate gradients
        loss.backward()

        # update weights
        optimizer.step()

        # zero autograd .grad after updating
        optimizer.zero_grad()
        
        if (i+1) % 100 == 0:
            print (f'Epoch [{epoch+1}/{n_supervised_epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.4f}')

print('Completed training.')

# Test the model
# In test phase, we don't need to compute gradients (helpful for memory efficiency) so use torch.no_grad()
with torch.no_grad():
    n_correct = 0
    n_samples = 0
    for images, labels in test_loader:
        images = images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        
        outputs = model(images)
        
        # max returns (value ,index)
        _, predicted = torch.max(outputs.data, 1)
        n_samples += labels.size(0)
        n_correct += (predicted == labels).sum().item()

    acc = 100.0 * n_correct / n_samples
    print(f'Accuracy of the network on the 10000 test images: {acc} %')

# OUTPUT
# Epoch [300/300], Step [600/600], Loss: 46022.9062
# Completed training.
# Accuracy of the network on the 10000 test images: 97.26 %

# %%
##### ------ THIS IS THE END OF MNIST WORK -------

# %%
# RESET weights (for my sanity)

weights_mnist = weights_mnist_frozen

# %%
# IGNITE
# REFERENCE: https://pytorch.org/ignite/quickstart.html, https://github.com/gatapia/unsupervised_bio_classifier

#def run_test(train_loader, test_loader, model, epochs, batch_size=64, lr=1e-3, verbose=0, loss=None):
def run_test(train_X, train_y, test_X, test_y, model, epochs, batch_size=64, lr=1e-3, verbose=0, loss=None):
    start = time()
    
    train_ds = torch.utils.data.TensorDataset(train_X, train_y)
    train_loader = torch.utils.data.DataLoader(train_ds, batch_size=batch_size, shuffle=True)
    test_ds = torch.utils.data.TensorDataset(test_X, test_y)
    test_loader = torch.utils.data.DataLoader(test_ds, batch_size=batch_size, shuffle=False)
    
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    if loss is None: 
        loss = F.nll_loss
    
    trainer = create_supervised_trainer(model, optimizer, loss, device=device)
    
    metrics = {
        'accuracy': Accuracy(),
        'nll': Loss(loss)   # TODO rename to 'loss'
    }
    
    evaluator = create_supervised_evaluator(model, metrics=metrics, device=device)
    
    # TODO rewrite print styles into my format
    
    @trainer.on(Events.ITERATION_COMPLETED(every=100))
    def log_training_loss(trainer):
        print("Epoch[{}] Loss: {:.2f}".format(trainer.state.epoch, trainer.state.output))
    
    @trainer.on(Events.EPOCH_COMPLETED)
    def log_training_results(trainer):
        evaluator.run(train_loader)
        metrics = evaluator.state.metrics
        avg_accuracy = metrics['accuracy']
        avg_nll = metrics['nll']
        print("Training Results - Epoch: {}  Avg accuracy: {:.2f} Avg loss: {:.2f}"
              .format(trainer.state.epoch, avg_accuracy, avg_nll))
    
    @trainer.on(Events.EPOCH_COMPLETED)
    def log_validation_results(trainer):
        evaluator.run(test_loader)
        metrics = evaluator.state.metrics
        avg_accuracy = metrics['accuracy']
        avg_nll = metrics['nll']
        print("Validation Results - Epoch: {}  Avg accuracy: {:.2f} Avg loss: {:.2f}"
              .format(trainer.state.epoch, avg_accuracy, avg_nll))
    
    @trainer.on(Events.COMPLETED)
    def log_completed_validation_results(trainer):
        evaluator.run(test_loader)
        metrics = evaluator.state.metrics
        avg_accuracy = metrics['accuracy']
        avg_nll = metrics['nll']
        print("Final Validation Results - Epoch: {}  Avg accuracy: {:.2f} Avg loss: {:.2f} Took: {:.0f}s"
              .format(trainer.state.epoch, avg_accuracy, avg_nll, time() - start))

    trainer.run(train_loader, max_epochs=epochs)

# %%
# https://github.com/gatapia/unsupervised_bio_classifier

def get_data(data_type):
    mat = scipy.io.loadmat('mnist_all.mat')
    X=torch.zeros((0, 28 * 28), dtype=torch.float)
    y=torch.zeros(0, dtype=torch.long)
    for i in range(10): 
        X_i = torch.from_numpy(mat[data_type + str(i)].astype(np.float)).float()
        X = torch.cat((X, X_i))
        y_i = torch.full(size=(len(X_i),), fill_value=i, dtype=torch.long)
        y = torch.cat((y, y_i))
    return X / 255.0, y

# %%
(train_X, train_y), (test_X, test_y) = get_data('train'), get_data('test')
print('train_data:', train_X.shape, train_y.shape)
print('test_data:', test_X.shape, test_y.shape)
# Out:
# train_data: torch.Size([60000, 784]) torch.Size([60000])
# test_data: torch.Size([10000, 784]) torch.Size([10000])

# %%
# MNIST dataset 
print("Downloading MNIST data...")
train_dataset = torchvision.datasets.MNIST(root='./data', 
                                           train=True, 
                                           transform=transforms.ToTensor(),  
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root='./data', 
                                          train=False, 
                                          transform=transforms.ToTensor())

print("Completed downloading MNIST data.")

# Data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=False)


print('\nBioClassifier w/ BioCell3 Model w/ BioLoss')
model = BioClassifier(BioCell3(weights_mnist)).to(device)
#run_test(train_X, train_y, test_X, test_y, model, 300, batch_size=3584, lr=1e-4, loss=BioLoss(m=6))
run_test(train_X, train_y, test_X, test_y, model, 300, batch_size=1024, lr=1e-4, loss=BioLoss(m=6))
#run_test(train_loader, test_loader, model, 300, batch_size=3584, lr=1e-4, loss=BioLoss(m=6))
# Out:
# Downloading MNIST data...
# Completed downloading MNIST data.
#
# BioClassifier w/ BioCell3 Model w/ BioLoss
# Training Results - Epoch: 1  Avg accuracy: 0.40 Avg loss: 1085829.29
# Validation Results - Epoch: 1  Avg accuracy: 0.40 Avg loss: 1059602.16
# Epoch[2] Loss: 886882.44
# Training Results - Epoch: 2  Avg accuracy: 0.56 Avg loss: 868932.69
# Validation Results - Epoch: 2  Avg accuracy: 0.56 Avg loss: 846026.45
# Training Results - Epoch: 3  Avg accuracy: 0.58 Avg loss: 835405.21
# Validation Results - Epoch: 3  Avg accuracy: 0.58 Avg loss: 814811.12
# Epoch[4] Loss: 819477.81
# Training Results - Epoch: 4  Avg accuracy: 0.64 Avg loss: 778383.35
# Validation Results - Epoch: 4  Avg accuracy: 0.64 Avg loss: 763971.92
# Training Results - Epoch: 5  Avg accuracy: 0.67 Avg loss: 745086.82
# Validation Results - Epoch: 5  Avg accuracy: 0.67 Avg loss: 732396.21
# Epoch[6] Loss: 752562.62
# Training Results - Epoch: 6  Avg accuracy: 0.74 Avg loss: 673331.06
# Validation Results - Epoch: 6  Avg accuracy: 0.74 Avg loss: 667150.54
# Epoch[7] Loss: 575774.94
# Training Results - Epoch: 7  Avg accuracy: 0.82 Avg loss: 585300.67
# Validation Results - Epoch: 7  Avg accuracy: 0.83 Avg loss: 576995.26
# Training Results - Epoch: 8  Avg accuracy: 0.83 Avg loss: 561666.70
# Validation Results - Epoch: 8  Avg accuracy: 0.84 Avg loss: 553597.78
# Epoch[9] Loss: 545864.38
# Training Results - Epoch: 9  Avg accuracy: 0.84 Avg loss: 549860.73
# Validation Results - Epoch: 9  Avg accuracy: 0.84 Avg loss: 545385.57
# Training Results - Epoch: 10  Avg accuracy: 0.84 Avg loss: 550254.45
# Validation Results - Epoch: 10  Avg accuracy: 0.84 Avg loss: 545381.73
# Epoch[11] Loss: 518894.12
# Training Results - Epoch: 11  Avg accuracy: 0.85 Avg loss: 534376.50
# Validation Results - Epoch: 11  Avg accuracy: 0.85 Avg loss: 532416.18
# Epoch[12] Loss: 533060.00
# Training Results - Epoch: 12  Avg accuracy: 0.85 Avg loss: 533338.61
# Validation Results - Epoch: 12  Avg accuracy: 0.85 Avg loss: 532873.06
# Training Results - Epoch: 13  Avg accuracy: 0.85 Avg loss: 523978.00
# Validation Results - Epoch: 13  Avg accuracy: 0.85 Avg loss: 523708.88
# Epoch[14] Loss: 524732.62
# Training Results - Epoch: 14  Avg accuracy: 0.85 Avg loss: 519056.44
# Validation Results - Epoch: 14  Avg accuracy: 0.86 Avg loss: 516631.70
# Training Results - Epoch: 15  Avg accuracy: 0.86 Avg loss: 513812.43
# Validation Results - Epoch: 15  Avg accuracy: 0.86 Avg loss: 513121.61
# Epoch[16] Loss: 534415.62
# Training Results - Epoch: 16  Avg accuracy: 0.86 Avg loss: 511478.61
# Validation Results - Epoch: 16  Avg accuracy: 0.86 Avg loss: 511771.16
# Epoch[17] Loss: 498562.31
# Training Results - Epoch: 17  Avg accuracy: 0.86 Avg loss: 508027.07
# Validation Results - Epoch: 17  Avg accuracy: 0.86 Avg loss: 507889.86
# Training Results - Epoch: 18  Avg accuracy: 0.91 Avg loss: 461831.74
# Validation Results - Epoch: 18  Avg accuracy: 0.91 Avg loss: 470670.13
# Epoch[19] Loss: 435943.75
# Training Results - Epoch: 19  Avg accuracy: 0.94 Avg loss: 432369.38
# Validation Results - Epoch: 19  Avg accuracy: 0.94 Avg loss: 431666.15
# Training Results - Epoch: 20  Avg accuracy: 0.94 Avg loss: 429488.63
# Validation Results - Epoch: 20  Avg accuracy: 0.94 Avg loss: 431903.36
# Epoch[21] Loss: 418948.59
# Training Results - Epoch: 21  Avg accuracy: 0.95 Avg loss: 417809.71
# Validation Results - Epoch: 21  Avg accuracy: 0.95 Avg loss: 416990.26
# Training Results - Epoch: 22  Avg accuracy: 0.95 Avg loss: 412863.06
# Validation Results - Epoch: 22  Avg accuracy: 0.95 Avg loss: 413683.88
# Epoch[23] Loss: 416594.06
# Training Results - Epoch: 23  Avg accuracy: 0.95 Avg loss: 414593.24
# Validation Results - Epoch: 23  Avg accuracy: 0.95 Avg loss: 413955.42
# Epoch[24] Loss: 428618.25
# Training Results - Epoch: 24  Avg accuracy: 0.95 Avg loss: 406599.25
# Validation Results - Epoch: 24  Avg accuracy: 0.95 Avg loss: 405710.05
# Training Results - Epoch: 25  Avg accuracy: 0.95 Avg loss: 404683.10
# Validation Results - Epoch: 25  Avg accuracy: 0.95 Avg loss: 405166.49
# Epoch[26] Loss: 406653.38
# Training Results - Epoch: 26  Avg accuracy: 0.96 Avg loss: 401400.68
# Validation Results - Epoch: 26  Avg accuracy: 0.95 Avg loss: 401403.90
# Training Results - Epoch: 27  Avg accuracy: 0.95 Avg loss: 409296.57
# Validation Results - Epoch: 27  Avg accuracy: 0.95 Avg loss: 409478.11
# Epoch[28] Loss: 411461.69
# Training Results - Epoch: 28  Avg accuracy: 0.96 Avg loss: 398116.04
# Validation Results - Epoch: 28  Avg accuracy: 0.96 Avg loss: 397971.11
# Epoch[29] Loss: 423760.38
# Training Results - Epoch: 29  Avg accuracy: 0.96 Avg loss: 393831.71
# Validation Results - Epoch: 29  Avg accuracy: 0.96 Avg loss: 397100.65
# Training Results - Epoch: 30  Avg accuracy: 0.96 Avg loss: 395973.89
# Validation Results - Epoch: 30  Avg accuracy: 0.95 Avg loss: 398355.60
# Epoch[31] Loss: 409544.00
# Training Results - Epoch: 31  Avg accuracy: 0.96 Avg loss: 394383.84
# Validation Results - Epoch: 31  Avg accuracy: 0.96 Avg loss: 396472.10
# Training Results - Epoch: 32  Avg accuracy: 0.96 Avg loss: 387462.31
# Validation Results - Epoch: 32  Avg accuracy: 0.96 Avg loss: 389332.13
# Epoch[33] Loss: 396473.25
# Training Results - Epoch: 33  Avg accuracy: 0.96 Avg loss: 387808.07
# Validation Results - Epoch: 33  Avg accuracy: 0.96 Avg loss: 389983.18
# Epoch[34] Loss: 399896.66
# Training Results - Epoch: 34  Avg accuracy: 0.96 Avg loss: 385785.88
# Validation Results - Epoch: 34  Avg accuracy: 0.96 Avg loss: 389192.43
# Training Results - Epoch: 35  Avg accuracy: 0.96 Avg loss: 396651.76
# Validation Results - Epoch: 35  Avg accuracy: 0.95 Avg loss: 395032.67
# Epoch[36] Loss: 394965.03
# Training Results - Epoch: 36  Avg accuracy: 0.96 Avg loss: 384540.23
# Validation Results - Epoch: 36  Avg accuracy: 0.96 Avg loss: 386955.65
# Training Results - Epoch: 37  Avg accuracy: 0.96 Avg loss: 381318.90
# Validation Results - Epoch: 37  Avg accuracy: 0.96 Avg loss: 385680.19
# Epoch[38] Loss: 394345.44
# Training Results - Epoch: 38  Avg accuracy: 0.97 Avg loss: 379655.38
# Validation Results - Epoch: 38  Avg accuracy: 0.96 Avg loss: 382678.32
# Epoch[39] Loss: 387186.31
# Training Results - Epoch: 39  Avg accuracy: 0.96 Avg loss: 379602.68
# Validation Results - Epoch: 39  Avg accuracy: 0.96 Avg loss: 385126.41
# Training Results - Epoch: 40  Avg accuracy: 0.97 Avg loss: 377379.22
# Validation Results - Epoch: 40  Avg accuracy: 0.96 Avg loss: 382037.07
# Epoch[41] Loss: 372730.19
# Training Results - Epoch: 41  Avg accuracy: 0.96 Avg loss: 380108.41
# Validation Results - Epoch: 41  Avg accuracy: 0.96 Avg loss: 384430.98
# Training Results - Epoch: 42  Avg accuracy: 0.97 Avg loss: 377849.36
# Validation Results - Epoch: 42  Avg accuracy: 0.96 Avg loss: 380081.39
# Epoch[43] Loss: 375034.69
# Training Results - Epoch: 43  Avg accuracy: 0.96 Avg loss: 392049.44
# Validation Results - Epoch: 43  Avg accuracy: 0.96 Avg loss: 393229.95
# Training Results - Epoch: 44  Avg accuracy: 0.97 Avg loss: 376548.87
# Validation Results - Epoch: 44  Avg accuracy: 0.97 Avg loss: 381609.59
# Epoch[45] Loss: 379138.38
# Training Results - Epoch: 45  Avg accuracy: 0.97 Avg loss: 377939.22
# Validation Results - Epoch: 45  Avg accuracy: 0.96 Avg loss: 379490.01
# Epoch[46] Loss: 365191.12
# Training Results - Epoch: 46  Avg accuracy: 0.97 Avg loss: 371854.97
# Validation Results - Epoch: 46  Avg accuracy: 0.97 Avg loss: 373833.83
# Training Results - Epoch: 47  Avg accuracy: 0.97 Avg loss: 374591.93
# Validation Results - Epoch: 47  Avg accuracy: 0.96 Avg loss: 377938.78
# Epoch[48] Loss: 362677.81
# Training Results - Epoch: 48  Avg accuracy: 0.97 Avg loss: 369272.08
# Validation Results - Epoch: 48  Avg accuracy: 0.96 Avg loss: 374408.15
# Training Results - Epoch: 49  Avg accuracy: 0.97 Avg loss: 376577.71
# Validation Results - Epoch: 49  Avg accuracy: 0.96 Avg loss: 383756.65
# Epoch[50] Loss: 376653.59
# Training Results - Epoch: 50  Avg accuracy: 0.97 Avg loss: 368540.52
# Validation Results - Epoch: 50  Avg accuracy: 0.97 Avg loss: 370787.94
# Epoch[51] Loss: 390987.28
# Training Results - Epoch: 51  Avg accuracy: 0.97 Avg loss: 369773.17
# Validation Results - Epoch: 51  Avg accuracy: 0.96 Avg loss: 373567.71
# Training Results - Epoch: 52  Avg accuracy: 0.97 Avg loss: 368816.32
# Validation Results - Epoch: 52  Avg accuracy: 0.96 Avg loss: 374254.60
# Epoch[53] Loss: 364665.81
# Training Results - Epoch: 53  Avg accuracy: 0.97 Avg loss: 370614.47
# Validation Results - Epoch: 53  Avg accuracy: 0.97 Avg loss: 375153.46
# Training Results - Epoch: 54  Avg accuracy: 0.97 Avg loss: 368395.18
# Validation Results - Epoch: 54  Avg accuracy: 0.97 Avg loss: 373686.87
# Epoch[55] Loss: 360627.25
# Training Results - Epoch: 55  Avg accuracy: 0.97 Avg loss: 366033.54
# Validation Results - Epoch: 55  Avg accuracy: 0.97 Avg loss: 371534.25
# Epoch[56] Loss: 375443.50
# Training Results - Epoch: 56  Avg accuracy: 0.97 Avg loss: 365185.78
# Validation Results - Epoch: 56  Avg accuracy: 0.97 Avg loss: 371734.16
# Training Results - Epoch: 57  Avg accuracy: 0.97 Avg loss: 373888.63
# Validation Results - Epoch: 57  Avg accuracy: 0.96 Avg loss: 376897.60
# Epoch[58] Loss: 373612.25
# Training Results - Epoch: 58  Avg accuracy: 0.97 Avg loss: 370079.48
# Validation Results - Epoch: 58  Avg accuracy: 0.97 Avg loss: 375308.39
# Training Results - Epoch: 59  Avg accuracy: 0.97 Avg loss: 370323.55
# Validation Results - Epoch: 59  Avg accuracy: 0.96 Avg loss: 377523.39
# Epoch[60] Loss: 372023.12
# Training Results - Epoch: 60  Avg accuracy: 0.97 Avg loss: 370511.15
# Validation Results - Epoch: 60  Avg accuracy: 0.96 Avg loss: 373552.48
# Training Results - Epoch: 61  Avg accuracy: 0.97 Avg loss: 366078.90
# Validation Results - Epoch: 61  Avg accuracy: 0.97 Avg loss: 371110.30
# Epoch[62] Loss: 365653.00
# Training Results - Epoch: 62  Avg accuracy: 0.97 Avg loss: 372816.06
# Validation Results - Epoch: 62  Avg accuracy: 0.96 Avg loss: 374366.78
# Epoch[63] Loss: 378840.88
# Training Results - Epoch: 63  Avg accuracy: 0.97 Avg loss: 364252.03
# Validation Results - Epoch: 63  Avg accuracy: 0.97 Avg loss: 370236.74
# Training Results - Epoch: 64  Avg accuracy: 0.97 Avg loss: 367427.21
# Validation Results - Epoch: 64  Avg accuracy: 0.97 Avg loss: 369541.71
# Epoch[65] Loss: 354525.00
# Training Results - Epoch: 65  Avg accuracy: 0.97 Avg loss: 367406.53
# Validation Results - Epoch: 65  Avg accuracy: 0.96 Avg loss: 376685.73
# Training Results - Epoch: 66  Avg accuracy: 0.97 Avg loss: 367337.61
# Validation Results - Epoch: 66  Avg accuracy: 0.96 Avg loss: 370959.56
# Epoch[67] Loss: 358034.94
# Training Results - Epoch: 67  Avg accuracy: 0.97 Avg loss: 362785.95
# Validation Results - Epoch: 67  Avg accuracy: 0.97 Avg loss: 370723.62
# Epoch[68] Loss: 357699.06
# Training Results - Epoch: 68  Avg accuracy: 0.97 Avg loss: 361381.19
# Validation Results - Epoch: 68  Avg accuracy: 0.97 Avg loss: 366259.39
# Training Results - Epoch: 69  Avg accuracy: 0.97 Avg loss: 364722.09
# Validation Results - Epoch: 69  Avg accuracy: 0.97 Avg loss: 370849.58
# Epoch[70] Loss: 366047.69
# Training Results - Epoch: 70  Avg accuracy: 0.97 Avg loss: 361928.12
# Validation Results - Epoch: 70  Avg accuracy: 0.97 Avg loss: 369537.56
# Training Results - Epoch: 71  Avg accuracy: 0.97 Avg loss: 359362.85
# Validation Results - Epoch: 71  Avg accuracy: 0.97 Avg loss: 365592.15
# Epoch[72] Loss: 370599.75
# Training Results - Epoch: 72  Avg accuracy: 0.97 Avg loss: 360071.02
# Validation Results - Epoch: 72  Avg accuracy: 0.97 Avg loss: 367075.53
# Epoch[73] Loss: 368233.19
# Training Results - Epoch: 73  Avg accuracy: 0.97 Avg loss: 362545.58
# Validation Results - Epoch: 73  Avg accuracy: 0.97 Avg loss: 370668.38
# Training Results - Epoch: 74  Avg accuracy: 0.97 Avg loss: 358954.45
# Validation Results - Epoch: 74  Avg accuracy: 0.97 Avg loss: 363260.14
# Epoch[75] Loss: 358361.69
# Training Results - Epoch: 75  Avg accuracy: 0.97 Avg loss: 358817.79
# Validation Results - Epoch: 75  Avg accuracy: 0.97 Avg loss: 365249.60
# Training Results - Epoch: 76  Avg accuracy: 0.97 Avg loss: 364773.76
# Validation Results - Epoch: 76  Avg accuracy: 0.97 Avg loss: 368174.15
# Epoch[77] Loss: 350022.81
# Training Results - Epoch: 77  Avg accuracy: 0.97 Avg loss: 359690.61
# Validation Results - Epoch: 77  Avg accuracy: 0.97 Avg loss: 368381.70
# Epoch[78] Loss: 376540.44
# Training Results - Epoch: 78  Avg accuracy: 0.97 Avg loss: 360177.00
# Validation Results - Epoch: 78  Avg accuracy: 0.97 Avg loss: 367491.53
# Training Results - Epoch: 79  Avg accuracy: 0.98 Avg loss: 353479.69
# Validation Results - Epoch: 79  Avg accuracy: 0.97 Avg loss: 361880.22
# Epoch[80] Loss: 359176.78
# Training Results - Epoch: 80  Avg accuracy: 0.98 Avg loss: 355274.41
# Validation Results - Epoch: 80  Avg accuracy: 0.97 Avg loss: 361044.39
# Training Results - Epoch: 81  Avg accuracy: 0.97 Avg loss: 365179.18
# Validation Results - Epoch: 81  Avg accuracy: 0.97 Avg loss: 370344.05
# Epoch[82] Loss: 348384.31
# Training Results - Epoch: 82  Avg accuracy: 0.98 Avg loss: 353898.04
# Validation Results - Epoch: 82  Avg accuracy: 0.97 Avg loss: 361379.12
# Training Results - Epoch: 83  Avg accuracy: 0.97 Avg loss: 355369.73
# Validation Results - Epoch: 83  Avg accuracy: 0.97 Avg loss: 363859.61
# Epoch[84] Loss: 368009.50
# Training Results - Epoch: 84  Avg accuracy: 0.97 Avg loss: 356640.68
# Validation Results - Epoch: 84  Avg accuracy: 0.97 Avg loss: 361627.91
# Epoch[85] Loss: 349330.25
# Training Results - Epoch: 85  Avg accuracy: 0.97 Avg loss: 354859.22
# Validation Results - Epoch: 85  Avg accuracy: 0.97 Avg loss: 359241.75
# Training Results - Epoch: 86  Avg accuracy: 0.98 Avg loss: 354068.28
# Validation Results - Epoch: 86  Avg accuracy: 0.97 Avg loss: 360760.63
# Epoch[87] Loss: 351375.12
# Training Results - Epoch: 87  Avg accuracy: 0.97 Avg loss: 358597.62
# Validation Results - Epoch: 87  Avg accuracy: 0.97 Avg loss: 364367.47
# Training Results - Epoch: 88  Avg accuracy: 0.97 Avg loss: 358356.31
# Validation Results - Epoch: 88  Avg accuracy: 0.97 Avg loss: 367204.95
# Epoch[89] Loss: 350016.75
# Training Results - Epoch: 89  Avg accuracy: 0.97 Avg loss: 358418.08
# Validation Results - Epoch: 89  Avg accuracy: 0.97 Avg loss: 366737.02
# Epoch[90] Loss: 352543.56
# Training Results - Epoch: 90  Avg accuracy: 0.98 Avg loss: 351495.18
# Validation Results - Epoch: 90  Avg accuracy: 0.97 Avg loss: 360009.99
# Training Results - Epoch: 91  Avg accuracy: 0.97 Avg loss: 360067.20
# Validation Results - Epoch: 91  Avg accuracy: 0.97 Avg loss: 368813.52
# Epoch[92] Loss: 363280.56
# Training Results - Epoch: 92  Avg accuracy: 0.98 Avg loss: 353918.09
# Validation Results - Epoch: 92  Avg accuracy: 0.97 Avg loss: 362709.68
# Training Results - Epoch: 93  Avg accuracy: 0.98 Avg loss: 354035.77
# Validation Results - Epoch: 93  Avg accuracy: 0.97 Avg loss: 358524.60
# Epoch[94] Loss: 361375.28
# Training Results - Epoch: 94  Avg accuracy: 0.98 Avg loss: 355596.04
# Validation Results - Epoch: 94  Avg accuracy: 0.97 Avg loss: 362577.09
# Epoch[95] Loss: 359507.56
# Training Results - Epoch: 95  Avg accuracy: 0.97 Avg loss: 354453.30
# Validation Results - Epoch: 95  Avg accuracy: 0.97 Avg loss: 360977.08
# Training Results - Epoch: 96  Avg accuracy: 0.97 Avg loss: 354126.86
# Validation Results - Epoch: 96  Avg accuracy: 0.97 Avg loss: 362886.70
# Epoch[97] Loss: 357013.06
# Training Results - Epoch: 97  Avg accuracy: 0.97 Avg loss: 356375.18
# Validation Results - Epoch: 97  Avg accuracy: 0.97 Avg loss: 366623.06
# Training Results - Epoch: 98  Avg accuracy: 0.98 Avg loss: 348703.91
# Validation Results - Epoch: 98  Avg accuracy: 0.97 Avg loss: 359484.11
# Epoch[99] Loss: 363462.69
# Training Results - Epoch: 99  Avg accuracy: 0.98 Avg loss: 351691.25
# Validation Results - Epoch: 99  Avg accuracy: 0.97 Avg loss: 359792.32
# Epoch[100] Loss: 219347.58
# Training Results - Epoch: 100  Avg accuracy: 0.98 Avg loss: 350174.95
# Validation Results - Epoch: 100  Avg accuracy: 0.97 Avg loss: 358976.42
# Training Results - Epoch: 101  Avg accuracy: 0.98 Avg loss: 349789.15
# Validation Results - Epoch: 101  Avg accuracy: 0.97 Avg loss: 360967.02
# Epoch[102] Loss: 351777.19
# Training Results - Epoch: 102  Avg accuracy: 0.98 Avg loss: 347232.49
# Validation Results - Epoch: 102  Avg accuracy: 0.97 Avg loss: 356039.42
# Training Results - Epoch: 103  Avg accuracy: 0.98 Avg loss: 354809.34
# Validation Results - Epoch: 103  Avg accuracy: 0.97 Avg loss: 362333.49
# Epoch[104] Loss: 351038.81
# Training Results - Epoch: 104  Avg accuracy: 0.98 Avg loss: 347974.86
# Validation Results - Epoch: 104  Avg accuracy: 0.97 Avg loss: 357860.42
# Training Results - Epoch: 105  Avg accuracy: 0.97 Avg loss: 363878.88
# Validation Results - Epoch: 105  Avg accuracy: 0.97 Avg loss: 366280.09
# Epoch[106] Loss: 365613.78
# Training Results - Epoch: 106  Avg accuracy: 0.98 Avg loss: 349028.35
# Validation Results - Epoch: 106  Avg accuracy: 0.97 Avg loss: 357538.18
# Epoch[107] Loss: 345503.31
# Training Results - Epoch: 107  Avg accuracy: 0.98 Avg loss: 348894.34
# Validation Results - Epoch: 107  Avg accuracy: 0.97 Avg loss: 359289.13
# Training Results - Epoch: 108  Avg accuracy: 0.98 Avg loss: 352967.11
# Validation Results - Epoch: 108  Avg accuracy: 0.97 Avg loss: 363080.89
# Epoch[109] Loss: 341406.53
# Training Results - Epoch: 109  Avg accuracy: 0.98 Avg loss: 356440.72
# Validation Results - Epoch: 109  Avg accuracy: 0.97 Avg loss: 363988.80
# Training Results - Epoch: 110  Avg accuracy: 0.98 Avg loss: 345412.06
# Validation Results - Epoch: 110  Avg accuracy: 0.97 Avg loss: 353696.22
# Epoch[111] Loss: 344608.75
# Training Results - Epoch: 111  Avg accuracy: 0.98 Avg loss: 348428.91
# Validation Results - Epoch: 111  Avg accuracy: 0.97 Avg loss: 360774.28
# Epoch[112] Loss: 350587.50
# Training Results - Epoch: 112  Avg accuracy: 0.98 Avg loss: 349507.16
# Validation Results - Epoch: 112  Avg accuracy: 0.97 Avg loss: 361192.69
# Training Results - Epoch: 113  Avg accuracy: 0.98 Avg loss: 352019.56
# Validation Results - Epoch: 113  Avg accuracy: 0.97 Avg loss: 356752.21
# Epoch[114] Loss: 364008.50
# Training Results - Epoch: 114  Avg accuracy: 0.98 Avg loss: 350772.18
# Validation Results - Epoch: 114  Avg accuracy: 0.97 Avg loss: 360901.45
# Training Results - Epoch: 115  Avg accuracy: 0.98 Avg loss: 350816.81
# Validation Results - Epoch: 115  Avg accuracy: 0.97 Avg loss: 361293.47
# Epoch[116] Loss: 348780.28
# Training Results - Epoch: 116  Avg accuracy: 0.98 Avg loss: 348992.73
# Validation Results - Epoch: 116  Avg accuracy: 0.97 Avg loss: 360514.89
# Epoch[117] Loss: 352844.31
# Training Results - Epoch: 117  Avg accuracy: 0.97 Avg loss: 362434.81
# Validation Results - Epoch: 117  Avg accuracy: 0.96 Avg loss: 372776.69
# Training Results - Epoch: 118  Avg accuracy: 0.98 Avg loss: 348175.36
# Validation Results - Epoch: 118  Avg accuracy: 0.97 Avg loss: 359539.83
# Epoch[119] Loss: 356357.78
# Training Results - Epoch: 119  Avg accuracy: 0.98 Avg loss: 347209.91
# Validation Results - Epoch: 119  Avg accuracy: 0.97 Avg loss: 355636.98
# Training Results - Epoch: 120  Avg accuracy: 0.98 Avg loss: 350362.96
# Validation Results - Epoch: 120  Avg accuracy: 0.97 Avg loss: 360650.35
# Epoch[121] Loss: 356170.72
# Training Results - Epoch: 121  Avg accuracy: 0.98 Avg loss: 348849.46
# Validation Results - Epoch: 121  Avg accuracy: 0.97 Avg loss: 358067.85
# Training Results - Epoch: 122  Avg accuracy: 0.98 Avg loss: 352420.41
# Validation Results - Epoch: 122  Avg accuracy: 0.97 Avg loss: 363919.45
# Epoch[123] Loss: 357609.69
# Training Results - Epoch: 123  Avg accuracy: 0.98 Avg loss: 350340.54
# Validation Results - Epoch: 123  Avg accuracy: 0.97 Avg loss: 358820.56
# Epoch[124] Loss: 341846.97
# Training Results - Epoch: 124  Avg accuracy: 0.98 Avg loss: 344594.25
# Validation Results - Epoch: 124  Avg accuracy: 0.97 Avg loss: 354258.00
# Training Results - Epoch: 125  Avg accuracy: 0.98 Avg loss: 354374.04
# Validation Results - Epoch: 125  Avg accuracy: 0.97 Avg loss: 367925.38
# Epoch[126] Loss: 337003.38
# Training Results - Epoch: 126  Avg accuracy: 0.98 Avg loss: 342806.95
# Validation Results - Epoch: 126  Avg accuracy: 0.97 Avg loss: 354792.35
# Training Results - Epoch: 127  Avg accuracy: 0.98 Avg loss: 342878.39
# Validation Results - Epoch: 127  Avg accuracy: 0.97 Avg loss: 354066.25
# Epoch[128] Loss: 360105.34
# Training Results - Epoch: 128  Avg accuracy: 0.98 Avg loss: 342209.26
# Validation Results - Epoch: 128  Avg accuracy: 0.97 Avg loss: 349901.49
# Epoch[129] Loss: 340875.06
# Training Results - Epoch: 129  Avg accuracy: 0.98 Avg loss: 350666.84
# Validation Results - Epoch: 129  Avg accuracy: 0.97 Avg loss: 359639.09
# Training Results - Epoch: 130  Avg accuracy: 0.98 Avg loss: 343996.94
# Validation Results - Epoch: 130  Avg accuracy: 0.97 Avg loss: 356924.61
# Epoch[131] Loss: 360851.75
# Training Results - Epoch: 131  Avg accuracy: 0.97 Avg loss: 362960.73
# Validation Results - Epoch: 131  Avg accuracy: 0.96 Avg loss: 370348.97
# Training Results - Epoch: 132  Avg accuracy: 0.98 Avg loss: 346230.36
# Validation Results - Epoch: 132  Avg accuracy: 0.97 Avg loss: 355145.27
# Epoch[133] Loss: 344357.53
# Training Results - Epoch: 133  Avg accuracy: 0.98 Avg loss: 346806.30
# Validation Results - Epoch: 133  Avg accuracy: 0.97 Avg loss: 361893.55
# Epoch[134] Loss: 349130.88
# Training Results - Epoch: 134  Avg accuracy: 0.98 Avg loss: 348181.47
# Validation Results - Epoch: 134  Avg accuracy: 0.97 Avg loss: 358860.45
# Training Results - Epoch: 135  Avg accuracy: 0.97 Avg loss: 359858.64
# Validation Results - Epoch: 135  Avg accuracy: 0.96 Avg loss: 371671.71
# Epoch[136] Loss: 341501.62
# Training Results - Epoch: 136  Avg accuracy: 0.98 Avg loss: 345677.50
# Validation Results - Epoch: 136  Avg accuracy: 0.97 Avg loss: 354929.87
# Training Results - Epoch: 137  Avg accuracy: 0.98 Avg loss: 345569.62
# Validation Results - Epoch: 137  Avg accuracy: 0.97 Avg loss: 359010.71
# Epoch[138] Loss: 336613.28
# Training Results - Epoch: 138  Avg accuracy: 0.98 Avg loss: 346451.34
# Validation Results - Epoch: 138  Avg accuracy: 0.97 Avg loss: 358308.89
# Epoch[139] Loss: 351394.38
# Training Results - Epoch: 139  Avg accuracy: 0.98 Avg loss: 348059.15
# Validation Results - Epoch: 139  Avg accuracy: 0.97 Avg loss: 358914.30
# Training Results - Epoch: 140  Avg accuracy: 0.98 Avg loss: 343232.29
# Validation Results - Epoch: 140  Avg accuracy: 0.97 Avg loss: 353981.27
# Epoch[141] Loss: 338337.19
# Training Results - Epoch: 141  Avg accuracy: 0.98 Avg loss: 344666.89
# Validation Results - Epoch: 141  Avg accuracy: 0.97 Avg loss: 356393.41
# Training Results - Epoch: 142  Avg accuracy: 0.98 Avg loss: 342771.36
# Validation Results - Epoch: 142  Avg accuracy: 0.97 Avg loss: 352559.30
# Epoch[143] Loss: 348495.41
# Training Results - Epoch: 143  Avg accuracy: 0.98 Avg loss: 346263.12
# Validation Results - Epoch: 143  Avg accuracy: 0.97 Avg loss: 357581.28
# Training Results - Epoch: 144  Avg accuracy: 0.98 Avg loss: 341687.64
# Validation Results - Epoch: 144  Avg accuracy: 0.97 Avg loss: 352349.61
# Epoch[145] Loss: 339029.41
# Training Results - Epoch: 145  Avg accuracy: 0.98 Avg loss: 341392.79
# Validation Results - Epoch: 145  Avg accuracy: 0.97 Avg loss: 352250.47
# Epoch[146] Loss: 339489.94
# Training Results - Epoch: 146  Avg accuracy: 0.98 Avg loss: 341835.84
# Validation Results - Epoch: 146  Avg accuracy: 0.97 Avg loss: 351692.37
# Training Results - Epoch: 147  Avg accuracy: 0.97 Avg loss: 357495.87
# Validation Results - Epoch: 147  Avg accuracy: 0.97 Avg loss: 367159.52
# Epoch[148] Loss: 329281.12
# Training Results - Epoch: 148  Avg accuracy: 0.98 Avg loss: 346339.42
# Validation Results - Epoch: 148  Avg accuracy: 0.97 Avg loss: 360337.27
# Training Results - Epoch: 149  Avg accuracy: 0.98 Avg loss: 340253.95
# Validation Results - Epoch: 149  Avg accuracy: 0.97 Avg loss: 351661.35
# Epoch[150] Loss: 339860.19
# Training Results - Epoch: 150  Avg accuracy: 0.98 Avg loss: 340874.97
# Validation Results - Epoch: 150  Avg accuracy: 0.97 Avg loss: 353704.67
# Epoch[151] Loss: 347856.56
# Training Results - Epoch: 151  Avg accuracy: 0.98 Avg loss: 343805.20
# Validation Results - Epoch: 151  Avg accuracy: 0.97 Avg loss: 354037.14
# Training Results - Epoch: 152  Avg accuracy: 0.98 Avg loss: 341227.00
# Validation Results - Epoch: 152  Avg accuracy: 0.97 Avg loss: 351684.46
# Epoch[153] Loss: 345403.12
# Training Results - Epoch: 153  Avg accuracy: 0.98 Avg loss: 343751.32
# Validation Results - Epoch: 153  Avg accuracy: 0.97 Avg loss: 353362.34
# Training Results - Epoch: 154  Avg accuracy: 0.98 Avg loss: 344590.37
# Validation Results - Epoch: 154  Avg accuracy: 0.97 Avg loss: 355362.24
# Epoch[155] Loss: 343563.06
# Training Results - Epoch: 155  Avg accuracy: 0.98 Avg loss: 345893.41
# Validation Results - Epoch: 155  Avg accuracy: 0.97 Avg loss: 356248.72
# Epoch[156] Loss: 345803.47
# Training Results - Epoch: 156  Avg accuracy: 0.94 Avg loss: 409636.74
# Validation Results - Epoch: 156  Avg accuracy: 0.93 Avg loss: 422539.07
# Training Results - Epoch: 157  Avg accuracy: 0.98 Avg loss: 339262.29
# Validation Results - Epoch: 157  Avg accuracy: 0.97 Avg loss: 351627.96
# Epoch[158] Loss: 341307.62
# Training Results - Epoch: 158  Avg accuracy: 0.98 Avg loss: 341216.97
# Validation Results - Epoch: 158  Avg accuracy: 0.97 Avg loss: 353385.64
# Training Results - Epoch: 159  Avg accuracy: 0.98 Avg loss: 353411.49
# Validation Results - Epoch: 159  Avg accuracy: 0.97 Avg loss: 361792.24
# Epoch[160] Loss: 345311.66
# Training Results - Epoch: 160  Avg accuracy: 0.98 Avg loss: 343486.81
# Validation Results - Epoch: 160  Avg accuracy: 0.97 Avg loss: 354091.17
# Training Results - Epoch: 161  Avg accuracy: 0.98 Avg loss: 338816.25
# Validation Results - Epoch: 161  Avg accuracy: 0.97 Avg loss: 348418.26
# Epoch[162] Loss: 338392.31
# Training Results - Epoch: 162  Avg accuracy: 0.98 Avg loss: 342317.99
# Validation Results - Epoch: 162  Avg accuracy: 0.97 Avg loss: 353196.62
# Epoch[163] Loss: 337209.38
# Training Results - Epoch: 163  Avg accuracy: 0.98 Avg loss: 338523.26
# Validation Results - Epoch: 163  Avg accuracy: 0.97 Avg loss: 352320.17
# Training Results - Epoch: 164  Avg accuracy: 0.98 Avg loss: 339928.68
# Validation Results - Epoch: 164  Avg accuracy: 0.97 Avg loss: 350416.43
# Epoch[165] Loss: 339118.75
# Training Results - Epoch: 165  Avg accuracy: 0.98 Avg loss: 348503.41
# Validation Results - Epoch: 165  Avg accuracy: 0.97 Avg loss: 358322.75
# Training Results - Epoch: 166  Avg accuracy: 0.98 Avg loss: 337874.39
# Validation Results - Epoch: 166  Avg accuracy: 0.97 Avg loss: 348553.38
# Epoch[167] Loss: 337383.19
# Training Results - Epoch: 167  Avg accuracy: 0.98 Avg loss: 339954.72
# Validation Results - Epoch: 167  Avg accuracy: 0.97 Avg loss: 353241.99
# Epoch[168] Loss: 353708.62
# Training Results - Epoch: 168  Avg accuracy: 0.98 Avg loss: 350490.03
# Validation Results - Epoch: 168  Avg accuracy: 0.97 Avg loss: 360994.22
# Training Results - Epoch: 169  Avg accuracy: 0.98 Avg loss: 338287.11
# Validation Results - Epoch: 169  Avg accuracy: 0.97 Avg loss: 350216.71
# Epoch[170] Loss: 346124.00
# Training Results - Epoch: 170  Avg accuracy: 0.98 Avg loss: 334784.83
# Validation Results - Epoch: 170  Avg accuracy: 0.97 Avg loss: 349210.59
# Training Results - Epoch: 171  Avg accuracy: 0.98 Avg loss: 349356.28
# Validation Results - Epoch: 171  Avg accuracy: 0.97 Avg loss: 358384.33
# Epoch[172] Loss: 338028.78
# Training Results - Epoch: 172  Avg accuracy: 0.98 Avg loss: 344948.29
# Validation Results - Epoch: 172  Avg accuracy: 0.97 Avg loss: 355905.74
# Epoch[173] Loss: 336554.97
# Training Results - Epoch: 173  Avg accuracy: 0.98 Avg loss: 342209.37
# Validation Results - Epoch: 173  Avg accuracy: 0.97 Avg loss: 352330.20
# Training Results - Epoch: 174  Avg accuracy: 0.98 Avg loss: 337873.85
# Validation Results - Epoch: 174  Avg accuracy: 0.97 Avg loss: 350648.58
# Epoch[175] Loss: 339609.62
# Training Results - Epoch: 175  Avg accuracy: 0.98 Avg loss: 340957.44
# Validation Results - Epoch: 175  Avg accuracy: 0.97 Avg loss: 355446.90
# Training Results - Epoch: 176  Avg accuracy: 0.98 Avg loss: 340315.07
# Validation Results - Epoch: 176  Avg accuracy: 0.97 Avg loss: 353669.02
# Epoch[177] Loss: 343220.06
# Training Results - Epoch: 177  Avg accuracy: 0.98 Avg loss: 338442.86
# Validation Results - Epoch: 177  Avg accuracy: 0.97 Avg loss: 352330.65
# Epoch[178] Loss: 343369.19
# Training Results - Epoch: 178  Avg accuracy: 0.98 Avg loss: 341166.28
# Validation Results - Epoch: 178  Avg accuracy: 0.97 Avg loss: 349994.06
# Training Results - Epoch: 179  Avg accuracy: 0.98 Avg loss: 345873.10
# Validation Results - Epoch: 179  Avg accuracy: 0.97 Avg loss: 358856.44
# Epoch[180] Loss: 327799.03
# Training Results - Epoch: 180  Avg accuracy: 0.98 Avg loss: 340933.96
# Validation Results - Epoch: 180  Avg accuracy: 0.97 Avg loss: 352268.94
# Training Results - Epoch: 181  Avg accuracy: 0.98 Avg loss: 340305.36
# Validation Results - Epoch: 181  Avg accuracy: 0.97 Avg loss: 352346.83
# Epoch[182] Loss: 342360.12
# Training Results - Epoch: 182  Avg accuracy: 0.98 Avg loss: 336231.50
# Validation Results - Epoch: 182  Avg accuracy: 0.97 Avg loss: 350243.03
# Training Results - Epoch: 183  Avg accuracy: 0.98 Avg loss: 344228.47
# Validation Results - Epoch: 183  Avg accuracy: 0.97 Avg loss: 353464.46
# Epoch[184] Loss: 345992.25
# Training Results - Epoch: 184  Avg accuracy: 0.98 Avg loss: 340661.05
# Validation Results - Epoch: 184  Avg accuracy: 0.97 Avg loss: 351896.35
# Epoch[185] Loss: 340605.62
# Training Results - Epoch: 185  Avg accuracy: 0.98 Avg loss: 338693.07
# Validation Results - Epoch: 185  Avg accuracy: 0.97 Avg loss: 349868.13
# Training Results - Epoch: 186  Avg accuracy: 0.98 Avg loss: 336039.76
# Validation Results - Epoch: 186  Avg accuracy: 0.97 Avg loss: 349204.37
# Epoch[187] Loss: 341695.03
# Training Results - Epoch: 187  Avg accuracy: 0.98 Avg loss: 337009.21
# Validation Results - Epoch: 187  Avg accuracy: 0.97 Avg loss: 352712.50
# Training Results - Epoch: 188  Avg accuracy: 0.98 Avg loss: 334920.68
# Validation Results - Epoch: 188  Avg accuracy: 0.97 Avg loss: 347618.53
# Epoch[189] Loss: 336229.66
# Training Results - Epoch: 189  Avg accuracy: 0.98 Avg loss: 340260.93
# Validation Results - Epoch: 189  Avg accuracy: 0.97 Avg loss: 352822.84
# Epoch[190] Loss: 333380.00
# Training Results - Epoch: 190  Avg accuracy: 0.98 Avg loss: 336518.95
# Validation Results - Epoch: 190  Avg accuracy: 0.97 Avg loss: 346959.45
# Training Results - Epoch: 191  Avg accuracy: 0.98 Avg loss: 336748.99
# Validation Results - Epoch: 191  Avg accuracy: 0.97 Avg loss: 353199.94
# Epoch[192] Loss: 359559.25
# Training Results - Epoch: 192  Avg accuracy: 0.98 Avg loss: 338119.27
# Validation Results - Epoch: 192  Avg accuracy: 0.97 Avg loss: 350969.72
# Training Results - Epoch: 193  Avg accuracy: 0.98 Avg loss: 338482.84
# Validation Results - Epoch: 193  Avg accuracy: 0.97 Avg loss: 349135.03
# Epoch[194] Loss: 336944.00
# Training Results - Epoch: 194  Avg accuracy: 0.98 Avg loss: 334796.69
# Validation Results - Epoch: 194  Avg accuracy: 0.97 Avg loss: 350090.80
# Epoch[195] Loss: 351373.94
# Training Results - Epoch: 195  Avg accuracy: 0.98 Avg loss: 338736.44
# Validation Results - Epoch: 195  Avg accuracy: 0.97 Avg loss: 351217.24
# Training Results - Epoch: 196  Avg accuracy: 0.98 Avg loss: 337524.93
# Validation Results - Epoch: 196  Avg accuracy: 0.97 Avg loss: 350474.98
# Epoch[197] Loss: 341337.72
# Training Results - Epoch: 197  Avg accuracy: 0.98 Avg loss: 332257.18
# Validation Results - Epoch: 197  Avg accuracy: 0.97 Avg loss: 346688.10
# Training Results - Epoch: 198  Avg accuracy: 0.98 Avg loss: 337126.88
# Validation Results - Epoch: 198  Avg accuracy: 0.97 Avg loss: 349551.46
# Epoch[199] Loss: 338471.09
# Training Results - Epoch: 199  Avg accuracy: 0.98 Avg loss: 333321.25
# Validation Results - Epoch: 199  Avg accuracy: 0.97 Avg loss: 346327.60
# Epoch[200] Loss: 199560.84
# Training Results - Epoch: 200  Avg accuracy: 0.98 Avg loss: 343562.72
# Validation Results - Epoch: 200  Avg accuracy: 0.97 Avg loss: 356407.36
# Training Results - Epoch: 201  Avg accuracy: 0.98 Avg loss: 338311.46
# Validation Results - Epoch: 201  Avg accuracy: 0.97 Avg loss: 351273.84
# Epoch[202] Loss: 342782.09
# Training Results - Epoch: 202  Avg accuracy: 0.98 Avg loss: 339090.24
# Validation Results - Epoch: 202  Avg accuracy: 0.97 Avg loss: 354951.11
# Training Results - Epoch: 203  Avg accuracy: 0.98 Avg loss: 337802.75
# Validation Results - Epoch: 203  Avg accuracy: 0.98 Avg loss: 348133.84
# Epoch[204] Loss: 336892.03
# Training Results - Epoch: 204  Avg accuracy: 0.98 Avg loss: 334889.78
# Validation Results - Epoch: 204  Avg accuracy: 0.97 Avg loss: 347958.41
# Training Results - Epoch: 205  Avg accuracy: 0.98 Avg loss: 338355.88
# Validation Results - Epoch: 205  Avg accuracy: 0.97 Avg loss: 352097.04
# Epoch[206] Loss: 337791.69
# Training Results - Epoch: 206  Avg accuracy: 0.98 Avg loss: 342484.54
# Validation Results - Epoch: 206  Avg accuracy: 0.97 Avg loss: 355576.02
# Epoch[207] Loss: 333445.00
# Training Results - Epoch: 207  Avg accuracy: 0.98 Avg loss: 336436.16
# Validation Results - Epoch: 207  Avg accuracy: 0.97 Avg loss: 348279.05
# Training Results - Epoch: 208  Avg accuracy: 0.98 Avg loss: 334435.65
# Validation Results - Epoch: 208  Avg accuracy: 0.97 Avg loss: 346423.07
# Epoch[209] Loss: 334791.03
# Training Results - Epoch: 209  Avg accuracy: 0.98 Avg loss: 333210.71
# Validation Results - Epoch: 209  Avg accuracy: 0.97 Avg loss: 347631.17
# Training Results - Epoch: 210  Avg accuracy: 0.98 Avg loss: 335852.57
# Validation Results - Epoch: 210  Avg accuracy: 0.97 Avg loss: 348151.38
# Epoch[211] Loss: 342836.69
# Training Results - Epoch: 211  Avg accuracy: 0.98 Avg loss: 337195.82
# Validation Results - Epoch: 211  Avg accuracy: 0.97 Avg loss: 349772.58
# Epoch[212] Loss: 336628.38
# Training Results - Epoch: 212  Avg accuracy: 0.98 Avg loss: 339939.48
# Validation Results - Epoch: 212  Avg accuracy: 0.97 Avg loss: 353160.50
# Training Results - Epoch: 213  Avg accuracy: 0.98 Avg loss: 336079.26
# Validation Results - Epoch: 213  Avg accuracy: 0.97 Avg loss: 347544.93
# Epoch[214] Loss: 331584.88
# Training Results - Epoch: 214  Avg accuracy: 0.98 Avg loss: 338328.19
# Validation Results - Epoch: 214  Avg accuracy: 0.97 Avg loss: 352073.78
# Training Results - Epoch: 215  Avg accuracy: 0.98 Avg loss: 339737.72
# Validation Results - Epoch: 215  Avg accuracy: 0.97 Avg loss: 350687.29
# Epoch[216] Loss: 338206.94
# Training Results - Epoch: 216  Avg accuracy: 0.98 Avg loss: 335703.68
# Validation Results - Epoch: 216  Avg accuracy: 0.97 Avg loss: 349409.85
# Epoch[217] Loss: 340844.44
# Training Results - Epoch: 217  Avg accuracy: 0.98 Avg loss: 332378.17
# Validation Results - Epoch: 217  Avg accuracy: 0.98 Avg loss: 345984.10
# Training Results - Epoch: 218  Avg accuracy: 0.98 Avg loss: 331268.46
# Validation Results - Epoch: 218  Avg accuracy: 0.97 Avg loss: 345931.40
# Epoch[219] Loss: 342048.81
# Training Results - Epoch: 219  Avg accuracy: 0.98 Avg loss: 341682.11
# Validation Results - Epoch: 219  Avg accuracy: 0.97 Avg loss: 353275.55
# Training Results - Epoch: 220  Avg accuracy: 0.98 Avg loss: 338902.40
# Validation Results - Epoch: 220  Avg accuracy: 0.97 Avg loss: 354081.55
# Epoch[221] Loss: 335845.75
# Training Results - Epoch: 221  Avg accuracy: 0.98 Avg loss: 332912.47
# Validation Results - Epoch: 221  Avg accuracy: 0.97 Avg loss: 346188.34
# Training Results - Epoch: 222  Avg accuracy: 0.98 Avg loss: 331896.73
# Validation Results - Epoch: 222  Avg accuracy: 0.98 Avg loss: 346095.68
# Epoch[223] Loss: 331670.66
# Training Results - Epoch: 223  Avg accuracy: 0.98 Avg loss: 337305.44
# Validation Results - Epoch: 223  Avg accuracy: 0.97 Avg loss: 350894.01
# Epoch[224] Loss: 329541.25
# Training Results - Epoch: 224  Avg accuracy: 0.98 Avg loss: 341838.71
# Validation Results - Epoch: 224  Avg accuracy: 0.97 Avg loss: 354007.02
# Training Results - Epoch: 225  Avg accuracy: 0.99 Avg loss: 331506.20
# Validation Results - Epoch: 225  Avg accuracy: 0.98 Avg loss: 345959.48
# Epoch[226] Loss: 332451.00
# Training Results - Epoch: 226  Avg accuracy: 0.98 Avg loss: 332673.74
# Validation Results - Epoch: 226  Avg accuracy: 0.97 Avg loss: 346891.09
# Training Results - Epoch: 227  Avg accuracy: 0.98 Avg loss: 336897.68
# Validation Results - Epoch: 227  Avg accuracy: 0.97 Avg loss: 352014.18
# Epoch[228] Loss: 334164.56
# Training Results - Epoch: 228  Avg accuracy: 0.98 Avg loss: 334880.77
# Validation Results - Epoch: 228  Avg accuracy: 0.97 Avg loss: 349530.99
# Epoch[229] Loss: 333703.16
# Training Results - Epoch: 229  Avg accuracy: 0.99 Avg loss: 329819.83
# Validation Results - Epoch: 229  Avg accuracy: 0.98 Avg loss: 346013.76
# Training Results - Epoch: 230  Avg accuracy: 0.98 Avg loss: 338556.00
# Validation Results - Epoch: 230  Avg accuracy: 0.97 Avg loss: 351970.69
# Epoch[231] Loss: 337561.03
# Training Results - Epoch: 231  Avg accuracy: 0.98 Avg loss: 332810.33
# Validation Results - Epoch: 231  Avg accuracy: 0.97 Avg loss: 349985.08
# Training Results - Epoch: 232  Avg accuracy: 0.99 Avg loss: 333324.86
# Validation Results - Epoch: 232  Avg accuracy: 0.98 Avg loss: 347389.97
# Epoch[233] Loss: 340044.22
# Training Results - Epoch: 233  Avg accuracy: 0.98 Avg loss: 335481.62
# Validation Results - Epoch: 233  Avg accuracy: 0.97 Avg loss: 350846.11
# Epoch[234] Loss: 343874.41
# Training Results - Epoch: 234  Avg accuracy: 0.98 Avg loss: 333519.63
# Validation Results - Epoch: 234  Avg accuracy: 0.98 Avg loss: 349272.27
# Training Results - Epoch: 235  Avg accuracy: 0.98 Avg loss: 338520.38
# Validation Results - Epoch: 235  Avg accuracy: 0.97 Avg loss: 350321.93
# Epoch[236] Loss: 334208.03
# Training Results - Epoch: 236  Avg accuracy: 0.98 Avg loss: 338238.42
# Validation Results - Epoch: 236  Avg accuracy: 0.97 Avg loss: 349024.65
# Training Results - Epoch: 237  Avg accuracy: 0.97 Avg loss: 368492.18
# Validation Results - Epoch: 237  Avg accuracy: 0.96 Avg loss: 382877.24
# Epoch[238] Loss: 344915.41
# Training Results - Epoch: 238  Avg accuracy: 0.98 Avg loss: 331797.11
# Validation Results - Epoch: 238  Avg accuracy: 0.97 Avg loss: 345316.20
# Epoch[239] Loss: 340887.78
# Training Results - Epoch: 239  Avg accuracy: 0.98 Avg loss: 335910.79
# Validation Results - Epoch: 239  Avg accuracy: 0.97 Avg loss: 349586.24
# Training Results - Epoch: 240  Avg accuracy: 0.99 Avg loss: 328831.25
# Validation Results - Epoch: 240  Avg accuracy: 0.97 Avg loss: 345032.97
# Epoch[241] Loss: 347279.50
# Training Results - Epoch: 241  Avg accuracy: 0.98 Avg loss: 337000.25
# Validation Results - Epoch: 241  Avg accuracy: 0.97 Avg loss: 349370.31
# Training Results - Epoch: 242  Avg accuracy: 0.98 Avg loss: 333615.47
# Validation Results - Epoch: 242  Avg accuracy: 0.97 Avg loss: 346744.63
# Epoch[243] Loss: 335997.00
# Training Results - Epoch: 243  Avg accuracy: 0.98 Avg loss: 335392.71
# Validation Results - Epoch: 243  Avg accuracy: 0.97 Avg loss: 345913.90
# Training Results - Epoch: 244  Avg accuracy: 0.98 Avg loss: 340195.72
# Validation Results - Epoch: 244  Avg accuracy: 0.97 Avg loss: 357442.28
# Epoch[245] Loss: 335790.84
# Training Results - Epoch: 245  Avg accuracy: 0.98 Avg loss: 338375.32
# Validation Results - Epoch: 245  Avg accuracy: 0.98 Avg loss: 350831.94
# Epoch[246] Loss: 343801.38
# Training Results - Epoch: 246  Avg accuracy: 0.98 Avg loss: 337984.48
# Validation Results - Epoch: 246  Avg accuracy: 0.97 Avg loss: 354085.80
# Training Results - Epoch: 247  Avg accuracy: 0.98 Avg loss: 341265.03
# Validation Results - Epoch: 247  Avg accuracy: 0.97 Avg loss: 350312.69
# Epoch[248] Loss: 331755.06
# Training Results - Epoch: 248  Avg accuracy: 0.98 Avg loss: 338958.04
# Validation Results - Epoch: 248  Avg accuracy: 0.97 Avg loss: 350796.72
# Training Results - Epoch: 249  Avg accuracy: 0.98 Avg loss: 335600.92
# Validation Results - Epoch: 249  Avg accuracy: 0.98 Avg loss: 350406.70
# Epoch[250] Loss: 336034.97
# Training Results - Epoch: 250  Avg accuracy: 0.98 Avg loss: 335774.74
# Validation Results - Epoch: 250  Avg accuracy: 0.97 Avg loss: 349011.46
# Epoch[251] Loss: 340641.94
# Training Results - Epoch: 251  Avg accuracy: 0.98 Avg loss: 337168.13
# Validation Results - Epoch: 251  Avg accuracy: 0.97 Avg loss: 350877.75
# Training Results - Epoch: 252  Avg accuracy: 0.98 Avg loss: 332722.87
# Validation Results - Epoch: 252  Avg accuracy: 0.97 Avg loss: 348409.46
# Epoch[253] Loss: 325455.09
# Training Results - Epoch: 253  Avg accuracy: 0.98 Avg loss: 335567.97
# Validation Results - Epoch: 253  Avg accuracy: 0.97 Avg loss: 352254.63
# Training Results - Epoch: 254  Avg accuracy: 0.98 Avg loss: 342028.49
# Validation Results - Epoch: 254  Avg accuracy: 0.97 Avg loss: 358055.01
# Epoch[255] Loss: 326088.25
# Training Results - Epoch: 255  Avg accuracy: 0.98 Avg loss: 332123.02
# Validation Results - Epoch: 255  Avg accuracy: 0.97 Avg loss: 346621.25
# Epoch[256] Loss: 336142.22
# Training Results - Epoch: 256  Avg accuracy: 0.99 Avg loss: 329765.06
# Validation Results - Epoch: 256  Avg accuracy: 0.98 Avg loss: 343592.41
# Training Results - Epoch: 257  Avg accuracy: 0.98 Avg loss: 336492.48
# Validation Results - Epoch: 257  Avg accuracy: 0.97 Avg loss: 352727.36
# Epoch[258] Loss: 332493.84
# Training Results - Epoch: 258  Avg accuracy: 0.99 Avg loss: 330888.81
# Validation Results - Epoch: 258  Avg accuracy: 0.97 Avg loss: 345936.77
# Training Results - Epoch: 259  Avg accuracy: 0.98 Avg loss: 335668.29
# Validation Results - Epoch: 259  Avg accuracy: 0.97 Avg loss: 354242.71
# Epoch[260] Loss: 342614.81
# Training Results - Epoch: 260  Avg accuracy: 0.98 Avg loss: 330326.19
# Validation Results - Epoch: 260  Avg accuracy: 0.97 Avg loss: 343951.72
# Training Results - Epoch: 261  Avg accuracy: 0.98 Avg loss: 330661.83
# Validation Results - Epoch: 261  Avg accuracy: 0.98 Avg loss: 345375.89
# Epoch[262] Loss: 328947.62
# Training Results - Epoch: 262  Avg accuracy: 0.98 Avg loss: 333062.36
# Validation Results - Epoch: 262  Avg accuracy: 0.98 Avg loss: 348811.30
# Epoch[263] Loss: 338014.31
# Training Results - Epoch: 263  Avg accuracy: 0.98 Avg loss: 344794.58
# Validation Results - Epoch: 263  Avg accuracy: 0.97 Avg loss: 355066.35
# Training Results - Epoch: 264  Avg accuracy: 0.98 Avg loss: 333269.99
# Validation Results - Epoch: 264  Avg accuracy: 0.97 Avg loss: 347211.21
# Epoch[265] Loss: 345695.91
# Training Results - Epoch: 265  Avg accuracy: 0.98 Avg loss: 336096.20
# Validation Results - Epoch: 265  Avg accuracy: 0.98 Avg loss: 350286.98
# Training Results - Epoch: 266  Avg accuracy: 0.99 Avg loss: 330263.04
# Validation Results - Epoch: 266  Avg accuracy: 0.98 Avg loss: 345181.22
# Epoch[267] Loss: 330274.91
# Training Results - Epoch: 267  Avg accuracy: 0.99 Avg loss: 331442.76
# Validation Results - Epoch: 267  Avg accuracy: 0.98 Avg loss: 345978.56
# Epoch[268] Loss: 340568.69
# Training Results - Epoch: 268  Avg accuracy: 0.98 Avg loss: 341005.39
# Validation Results - Epoch: 268  Avg accuracy: 0.97 Avg loss: 354007.94
# Training Results - Epoch: 269  Avg accuracy: 0.99 Avg loss: 327463.36
# Validation Results - Epoch: 269  Avg accuracy: 0.98 Avg loss: 344248.72
# Epoch[270] Loss: 331630.50
# Training Results - Epoch: 270  Avg accuracy: 0.98 Avg loss: 337223.89
# Validation Results - Epoch: 270  Avg accuracy: 0.97 Avg loss: 349497.63
# Training Results - Epoch: 271  Avg accuracy: 0.99 Avg loss: 330408.38
# Validation Results - Epoch: 271  Avg accuracy: 0.98 Avg loss: 345778.74
# Epoch[272] Loss: 329086.28
# Training Results - Epoch: 272  Avg accuracy: 0.99 Avg loss: 330554.74
# Validation Results - Epoch: 272  Avg accuracy: 0.98 Avg loss: 344948.23
# Epoch[273] Loss: 325697.75
# Training Results - Epoch: 273  Avg accuracy: 0.99 Avg loss: 330734.22
# Validation Results - Epoch: 273  Avg accuracy: 0.97 Avg loss: 346257.18
# Training Results - Epoch: 274  Avg accuracy: 0.99 Avg loss: 333217.43
# Validation Results - Epoch: 274  Avg accuracy: 0.97 Avg loss: 346752.93
# Epoch[275] Loss: 336070.94
# Training Results - Epoch: 275  Avg accuracy: 0.99 Avg loss: 328276.94
# Validation Results - Epoch: 275  Avg accuracy: 0.98 Avg loss: 342474.04
# Training Results - Epoch: 276  Avg accuracy: 0.98 Avg loss: 328942.85
# Validation Results - Epoch: 276  Avg accuracy: 0.97 Avg loss: 344981.00
# Epoch[277] Loss: 322111.28
# Training Results - Epoch: 277  Avg accuracy: 0.99 Avg loss: 328360.22
# Validation Results - Epoch: 277  Avg accuracy: 0.98 Avg loss: 341110.53
# Epoch[278] Loss: 345386.00
# Training Results - Epoch: 278  Avg accuracy: 0.99 Avg loss: 330211.05
# Validation Results - Epoch: 278  Avg accuracy: 0.98 Avg loss: 344016.90
# Training Results - Epoch: 279  Avg accuracy: 0.99 Avg loss: 331577.75
# Validation Results - Epoch: 279  Avg accuracy: 0.97 Avg loss: 347979.96
# Epoch[280] Loss: 345781.09
# Training Results - Epoch: 280  Avg accuracy: 0.99 Avg loss: 328039.81
# Validation Results - Epoch: 280  Avg accuracy: 0.97 Avg loss: 345272.03
# Training Results - Epoch: 281  Avg accuracy: 0.98 Avg loss: 333140.91
# Validation Results - Epoch: 281  Avg accuracy: 0.97 Avg loss: 345689.13
# Epoch[282] Loss: 333821.56
# Training Results - Epoch: 282  Avg accuracy: 0.98 Avg loss: 337189.42
# Validation Results - Epoch: 282  Avg accuracy: 0.97 Avg loss: 354237.12
# Training Results - Epoch: 283  Avg accuracy: 0.99 Avg loss: 330913.56
# Validation Results - Epoch: 283  Avg accuracy: 0.98 Avg loss: 346563.21
# Epoch[284] Loss: 330915.25
# Training Results - Epoch: 284  Avg accuracy: 0.98 Avg loss: 335324.13
# Validation Results - Epoch: 284  Avg accuracy: 0.97 Avg loss: 349462.57
# Epoch[285] Loss: 325721.91
# Training Results - Epoch: 285  Avg accuracy: 0.99 Avg loss: 330907.08
# Validation Results - Epoch: 285  Avg accuracy: 0.98 Avg loss: 345831.01
# Training Results - Epoch: 286  Avg accuracy: 0.98 Avg loss: 338473.92
# Validation Results - Epoch: 286  Avg accuracy: 0.98 Avg loss: 352593.25
# Epoch[287] Loss: 338588.59
# Training Results - Epoch: 287  Avg accuracy: 0.98 Avg loss: 341154.01
# Validation Results - Epoch: 287  Avg accuracy: 0.97 Avg loss: 351236.51
# Training Results - Epoch: 288  Avg accuracy: 0.98 Avg loss: 337539.25
# Validation Results - Epoch: 288  Avg accuracy: 0.97 Avg loss: 350127.04
# Epoch[289] Loss: 330745.12
# Training Results - Epoch: 289  Avg accuracy: 0.99 Avg loss: 331957.81
# Validation Results - Epoch: 289  Avg accuracy: 0.98 Avg loss: 346022.99
# Epoch[290] Loss: 336806.09
# Training Results - Epoch: 290  Avg accuracy: 0.99 Avg loss: 331825.67
# Validation Results - Epoch: 290  Avg accuracy: 0.98 Avg loss: 346391.80
# Training Results - Epoch: 291  Avg accuracy: 0.98 Avg loss: 333251.05
# Validation Results - Epoch: 291  Avg accuracy: 0.97 Avg loss: 350543.59
# Epoch[292] Loss: 327388.81
# Training Results - Epoch: 292  Avg accuracy: 0.98 Avg loss: 334674.25
# Validation Results - Epoch: 292  Avg accuracy: 0.97 Avg loss: 348746.80
# Training Results - Epoch: 293  Avg accuracy: 0.99 Avg loss: 330002.97
# Validation Results - Epoch: 293  Avg accuracy: 0.97 Avg loss: 346315.00
# Epoch[294] Loss: 329150.81
# Training Results - Epoch: 294  Avg accuracy: 0.99 Avg loss: 332030.84
# Validation Results - Epoch: 294  Avg accuracy: 0.98 Avg loss: 345292.74
# Epoch[295] Loss: 323165.25
# Training Results - Epoch: 295  Avg accuracy: 0.99 Avg loss: 328953.28
# Validation Results - Epoch: 295  Avg accuracy: 0.98 Avg loss: 342431.46
# Training Results - Epoch: 296  Avg accuracy: 0.99 Avg loss: 326375.45
# Validation Results - Epoch: 296  Avg accuracy: 0.97 Avg loss: 343599.64
# Epoch[297] Loss: 336524.75
# Training Results - Epoch: 297  Avg accuracy: 0.98 Avg loss: 342258.79
# Validation Results - Epoch: 297  Avg accuracy: 0.97 Avg loss: 357651.52
# Training Results - Epoch: 298  Avg accuracy: 0.98 Avg loss: 339820.63
# Validation Results - Epoch: 298  Avg accuracy: 0.97 Avg loss: 353450.42
# Epoch[299] Loss: 332369.44
# Training Results - Epoch: 299  Avg accuracy: 0.98 Avg loss: 333361.61
# Validation Results - Epoch: 299  Avg accuracy: 0.97 Avg loss: 347681.45
# Epoch[300] Loss: 195249.00
# Training Results - Epoch: 300  Avg accuracy: 0.99 Avg loss: 327501.54
# Validation Results - Epoch: 300  Avg accuracy: 0.98 Avg loss: 341365.29
# Final Validation Results - Epoch: 300  Avg accuracy: 0.98 Avg loss: 341365.29 Took: 376s

# %%
# BELOW IS WORK FOR CIFAR-10
# ALL WORK IN PROGRESS

# %%
# LOAD AND PREPARE CIFAR-10 DATA
# REFERENCE: https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html

# Keeping here for reference. From link above.
# As per the 'hidden competing units' paper, no need to Normalize as provided in the link.
# The dataset has PILImage images of range [0, 1]. 
# We transform them to Tensors of normalized range [-1, 1]
#transform = transforms.Compose(
#    [transforms.ToTensor(),
#     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# The CIFAR-10 dataset has PILImage images of range [0, 1]. 
# As mentioned in the 'hidden competing units' paper, "no preprocessing of the data was used except that
# each input image was normalized to be a unit vector in the 32x32x3 = 3072-dimensional space."
# We transform the images to Tensors here, and normalize to unit vectors further on in this cell.
transform = transforms.Compose([transforms.ToTensor()])

# CIFAR10: 60000 32x32 color images in 10 classes, with 6000 images per class
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                             download=True, transform=transform)

test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                            download=True, transform=transform)


cifar_classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# Test function to display an image
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# Display some random training images
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=1)
dataiter = iter(train_loader)
images, labels = dataiter.next()
print(images.shape)
print(labels.shape)
#imshow(torchvision.utils.make_grid(images))

# %%
# RUN UNSUPERVISED 'BIO' LEARNING ALGORITHM for CIFAR

# WORK IN PROGRESS

# Calculates weights for data and provided number of hidden units (given other configuration)
weights_cifar = get_unsupervised_weights(data_cifar, n_hidden, n_epochs, batch_size, learning_rate, precision, 
                                         anti_hebbian_learning_strength, lebesgue_norm, rank)
print(weights_cifar.shape)
print(weights_cifar)

# %%
# Draw CIFAR-10 weights/feature detectors generated by unsupervised bio algo

# WORK IN PROGRESS

def draw_weights(synapses, Kx, Ky):
    print(synapses)
    print(synapses.shape) # (100, 3072)
    yy=0
    HM=np.zeros((32*Ky,32*Kx,3))
    print(HM.shape) # (320, 320, 3)
    for y in range(Ky):
        for x in range(Kx):

            shit = synapses[yy,:]
            shit_reshape = synapses[yy,:].reshape(3,32,32)

            #print(synapses.shape)   # (100, 3072)
            #print(shit.shape)          # (3072,)
            #print(shit_reshape.shape)  # (3, 32, 32)

            #HM[y*28:(y+1)*28,x*28:(x+1)*28]=synapses[yy,:].reshape(28,28)
            HM[y*32:(y+1)*32,x*32:(x+1)*32,:]=synapses[yy,:].reshape(32,32,3)

            #HM[z, y*32:(y+1)*32,x*32:(x+1)*32]=synapses[yy,:].reshape(3,32,32)
            yy += 1
    print("Done with the fucking loop")
    plt.clf()
    nc=np.amax(np.absolute(HM))
    im=plt.imshow(HM[:,:,0],cmap='bwr',vmin=-nc,vmax=nc)
    fig.colorbar(im,ticks=[np.amin(HM), 0, np.amax(HM)])
    plt.axis('off')
    fig.canvas.draw()

# %matplotlib inline
# %matplotlib notebook
fig=plt.figure(figsize=(12.9,10))
draw_weights(weights_cifar, Kx, Ky)
print("Fin")

# %%
# USE THIS BLOCK FOR DEBUGGING PURPOSES ONLY !!

# Contains data loading and whole bio learning in one block of code.
# Plots the feature detectors at the end of training.

# LOAD AND PREPARE DATA

print("Loading MNIST...")
mat = scipy.io.loadmat('mnist_all.mat')
print("Done loading MNIST")

Nc=10 # output nodes
N=784 # number of pixels for each image. 28x28

M=np.zeros((0,N))
for i in range(Nc):
    M=np.concatenate((M, mat['train'+str(i)]), axis=0)
M=M/255.0

data = M
num_samples = data.shape[0]   # 60000 training and validation examples. Number of samples
num_features = data.shape[1]  # number of pixels for each image. 28x28. Also: num_samples, num_pixels..

# ------------------------------------------------------------------------------------------------------------

# UNSUPERVISED 'BIO' LEARNING ALGORITHM

# Initialize weights to be values drawn from gaussian distribution.
synapses = np.random.normal(mu, sigma, (n_hidden, N)).astype(np.float32)
weights = torch.from_numpy(synapses).to(device)

# The external loop runs over epochs
for epoch in range(n_epochs):
    eps = learning_rate * (1 - epoch / n_epochs)
    #print(f'epoch learning rate: {eps}')
    
    # Scramble the images and values. So that when making a
    # mini batch, random values/images will be chosen on each iteration.
    random_permutation_samples = np.random.permutation(num_samples)
    shuffled_epoch_data = data[random_permutation_samples,:]
    
    # Internal loop runs over minibatches    
    for i in range(num_samples // batch_size):        
        # For every minibatch the overlap with the data (tot_input) is 
        # calculated for each data point and each hidden unit.
        mini_batch = shuffled_epoch_data[i*batch_size:(i+1)*batch_size,:].astype(np.float32)
        mini_batch = torch.from_numpy(mini_batch).to(device)           
        mini_batch = torch.transpose(mini_batch, 0, 1)
        
        sign = torch.sign(weights)            
        W = sign * torch.abs(weights) ** (lebesgue_norm - 1)    
        # https://stackoverflow.com/questions/44524901/how-to-do-product-of-matrices-in-pytorch
        tot_input_torch = torch.mm(W, mini_batch)
                
        # The sorted strengths of the activations are stored in y. 
        # The variable yl stores the activations of the post synaptic cells - 
        # it is denoted by g(Q) in Eq 3 of 'Unsupervised Learning by Competing Hidden Units', see also Eq 9 and Eq 10.        
        y_torch = torch.argsort(tot_input_torch, dim=0)            
        yl_torch = torch.zeros((n_hidden, batch_size), dtype = torch.float).to(device)
        yl_torch[y_torch[n_hidden-1,:], torch.arange(batch_size)] = 1.0
        yl_torch[y_torch[n_hidden-rank], torch.arange(batch_size)] = -anti_hebbian_learning_strength
        
        # The variable ds is the right hand side of Eq 3        
        xx_torch = torch.sum(yl_torch * tot_input_torch,1)  
        xx_torch = xx_torch.unsqueeze(1)                    
        xx_torch = xx_torch.repeat(1, num_features)
        ds_torch = torch.mm(yl_torch, torch.transpose(mini_batch, 0, 1)) - (xx_torch * weights)
        
        # Update weights
        # The weights are updated after each minibatch in a way so that the largest update 
        # is equal to the learning rate eps at that epoch.        
        nc_torch = torch.max(torch.abs(ds_torch))
        if nc_torch < precision: 
            nc_torch = precision            
        weights += eps*(ds_torch/nc_torch)
        
        #if (i+1) % 100 == 0:
        #    print (f'Epoch [{epoch+1}/{n_epochs}], Step [{i+1}/{num_samples // batch_size}]')
        
    print (f'Epoch [{epoch+1}/{n_epochs}]')
    #draw_weights(weights.numpy(), Kx, Ky)

# %matplotlib inline
# %matplotlib notebook
fig=plt.figure(figsize=(12.9,10))
draw_weights(weights.cpu().numpy(), Kx, Ky)
print("Fin")
